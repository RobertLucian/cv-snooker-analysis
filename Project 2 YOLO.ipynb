# %%
from PIL import Image
from os import path, makedirs
import os
import re
import pandas as pd
import sys
import argparse
import glob
import tensorflow as tf
import numpy as np
import IPython.display as display
from absl.flags import FLAGS
from absl import app, flags, logging
from absl.flags import FLAGS

# %%
#must be executed at the beginning of the program
tf.enable_eager_execution()

# %%
base_folder='C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export'
tfr_records = glob.glob(os.path.join(base_folder, "*.tfrecord")) 
tfr_records.sort(key = len) 
print(tfr_records)
# Out:
# ['C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\0.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\1.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\2.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\3.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\4.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\5.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\10.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\11.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\12.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\13.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\14.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\15.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\16.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\17.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\20.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\21.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\22.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\23.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\24.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\25.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\26.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\27.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\28.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\29.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\30.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\31.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\32.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\33.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\34.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\35.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\36.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\37.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\40.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\41.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\42.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\43.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\44.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\45.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\46 ...

# %%
filenames = [tfr_records]
raw_dataset = tf.data.TFRecordDataset(filenames)
raw_dataset
# Out:
# <TFRecordDatasetV1 shapes: (), types: tf.string>

# %%
for raw_record in raw_dataset.take(2):
    print(repr(raw_record))
# Out:
# <tf.Tensor: id=20, shape=(), dtype=string, numpy=b'\n\x87\xd9\x0c\n\xc9\xd2\x0c\n\rimage/encoded\x12\xb6\xd2\x0c\n\xb2\xd2\x0c\n\xae\xd2\x0c\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x02\x01\x01\x01\x01\x01\x02\x01\x01\x01\x02\x02\x02\x02\x02\x04\x03\x02\x02\x02\x02\x05\x04\x04\x03\x04\x06\x05\x06\x06\x06\x05\x06\x06\x06\x07\t\x08\x06\x07\t\x07\x06\x06\x08\x0b\x08\t\n\n\n\n\n\x06\x08\x0b\x0c\x0b\n\x0c\t\n\n\n\xff\xdb\x00C\x01\x02\x02\x02\x02\x02\x02\x05\x03\x03\x05\n\x07\x06\x07\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xff\xc0\x00\x11\x08\x02\xd0\x05\x00\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xfc\xc3\xfd\x95\xbff\xab?\x16j:^\x9d}\xe1\xf8\xb5_\x18jz\\z\xc6\x95\xa4\xdfK\xb2\x08-\xbe\xd0\xa9\x1f\x9d\x19\xc8\x9d\xa5\x04\xb8L\x12\x88\x8a\xdb$2\x05_p\xb9\xfd\x96.<_\xf0\xcf\xe2&\x94\xf3\xf8C\xc4\x9a\xbe\x87vm<<4\x11\x06\x93oa2\xc1\x14\xb3\xc94\xb0E\x89B4\x9eZG\x85\x12ylx\xe8<\xa2\xeb\xe2w\x8c4\xaf\x87\xbe\x17\xf8\x8b\xe0\xaf\x0f\xf8F\xe6\xc2\xc7\xc3\xb6ZE\xd5\xdd\xff\x00\x84m\xae\xa7\xb5\xb9\xb5\x88@\xc9<\xa57\x1d\xca\x82E\xc8\xe8\xf8\xe7\x19\xaf\xa8\xbfc\x8f\x17\xeb\xfe\x18\xf8U\xab\xf8\xe3\xe2\xa6\x99\xe1m\x12\xd3V\x84_\xd8\xb6\x8d\xa5[Y\x83\x14h\xed,\xf3\x1bu\xda\xc4\x16@\xa8y\x19c\xc6k\xf5\x7f\xf8Y\x86+\xeb\x14*r\xcf\xbd\xaez\x9e\xc1%\xa1\xf9_\xe2\x8d3\xc4\x167\xd2\xdb\xeb6RG$NR@\xcaF\x18\x1c\x11\xc8\x1d\xc5c\xa0\t \xc9\xfd+\xd7\xbflO\xda\x1d\xff\x00i\x1f\x8c\x9a\x9f\xc4{\xbb3\x07\x9eR;8\x8bd\xc7\n(U\x04\xf78\x19\xf6\xcdx\xf1\x91\x8b\xf2y\xf5\xaf#\x1f\x8a\xafRju\xa4\xa5\'\xd4\xe1p\x8cdm\xe9\xeb\x96\x075<\xcb\x95\xf9y\xad\xff\x00\x07\xf8\x7fM\xd44X\xee\'\x8
#   feature {
#     key: "image/filename"
#     value {
#       bytes_list {
#         value: "0.jpg"
#       }
#     }
#   }
#   feature {
#     key: "image/format"
#     value {
#       bytes_list {
#         value: "jpg"
#       }
#     }
#   }
#   feature {
#     key: "image/height"
#     value {
#       int64_list {
#         value: 720
#       }
#     }
#   }
#   feature {
#     key: "image/key/sha256"
#     value {
#       bytes_list {
#         value: "TqXFCKZWbnYkBUP4/rBv1Fd3e+OVScQBZDav2mXSMw4="
#       }
#     }
#   }
#   feature {
#     key: "image/object/bbox/xmax"
#     value {
#       float_list {
#         value: 0.1340206116437912
#         value: 0.21124647557735443
#         value: 0.34245550632476807
#         value: 0.4099344313144684
#         value: 0.4624180197715759
#         value: 0.5613870620727539
#         value: 0.7308341264724731
#         value: 0.6146204471588135
#         value: 0.5306466817855835
#       }
#     }
#   }
#   feature {
#     key: "image/object/bbox/xmin"
#     value {
#       float_list {
#         value: 0.10702906548976898
#         value: 0.17525772750377655
#         value: 0.30571696162223816
#         value: 0.3799437880516052
#         value: 0.4316776394844055
#         value: 0.5306466817855835
#         value: 0.6985942125320435
#         value: 0.5801312327384949
#         value: 0.4999063014984131
#       }
#     }
#   }
#   feature {
#     key: "image/object/bbox/ymax"
#     value {
#       float_list {
#         value: 0.515500009059906
#         value: 0.6301666498184204
#         value: 0.6475000381469727
#         value: 0.5741666555404663
#         value: 0.5901666283607483
#         value: 0.6261667013168335
#         value: 0.6554999947547913
#         value: 0.6475000381469727
#         value: 0.6048333644866943
#       }
#     }
#   }
#   feature {
#     key: "image/object/bbox/ymin"
#     value {
#       float_list {
#         value: 0.468833327293396
#         value: 0.5741666555404663
#         value: 0.5861666798591614
#         value: 0.5234999656677246
#         value: 0.5368333458900452
#         value: 0.5755000114440918
#         value: 0.5968332886695862
#         value: 0.5821666717529297
#         value: 0.54749995470047
#       }
#     }
#   }
#   feature {
#     key: "image/object/class/label"
#     value {
#       int64_list {
#         value: 0
#         value: 0
#         value: 0
#         value: 0
#         value: 0
#         value: 0
#         value: 0
#         value: 0
#         value: 0
#       }
#     }
#   }
#   feature {
#     key: "image/object/class/text"
#     value {
#       bytes_list {
#         value: "ball"
#         value: "ball"
#         value: "ball"
#         value: "ball"
#         value: "ball"
#         value: "ball"
#         value: "ball"
#         value: "ball"
#         value: "ball"
#       }
#     }
#   }
#   feature {
#     key: "image/object/difficult"
#     value {
#       int64_list {
#         value: 0
#         value: 0
#         value: 0
#         value: 0
#         value: 0
#         value: 0
#         value: 0
#         value: 0
#         value: 0
#       }
#     }
#   }
#   feature {
#     key: "image/object/truncated"
#     value {
#       int64_list {
#         value: 0
#         value: 0
#         value: 0
#         value: 0
#         value: 0
#         value: 0
#         value: 0
#         value: 0
#         value: 0
#       }
#     }
#   }
#   feature {
#     key: "image/object/view"
#     value {
#       bytes_list {
#         value: "Unspecified"
#         value: "Unspecified"
#         value: "Unspecified"
#         value: "Unspecified"
#         value: "Unspecified"
#         value: "Unspecified"
#         value: "Unspecified"
#         value: "Unspecified"
#         value: "Unspecified"
#       }
#     }
#   }
#   feature {
#     key: "image/source_id"
#     value {
#       bytes_list {
#         value: "0.jpg"
#       }
#     }
#   }
#   feature {
#     key: "image/width"
#     value {
#       int64_list {
#         value: 1280
#       }
#     }
#   }
# }

# %%
@tf.function
def transform_targets_for_output(y_true, grid_size, anchor_idxs):
    # y_true: (N, boxes, (x1, y1, x2, y2, class, best_anchor))
    N = tf.shape(y_true)[0]

    # y_true_out: (N, grid, grid, anchors, [x, y, w, h, obj, class])
    y_true_out = tf.zeros(
        (N, grid_size, grid_size, tf.shape(anchor_idxs)[0], 6))

    anchor_idxs = tf.cast(anchor_idxs, tf.int32)

    indexes = tf.TensorArray(tf.int32, 1, dynamic_size=True)
    updates = tf.TensorArray(tf.float32, 1, dynamic_size=True)
    idx = 0
    for i in tf.range(N):
        for j in tf.range(tf.shape(y_true)[1]):
            if tf.equal(y_true[i][j][2], 0):
                continue
            anchor_eq = tf.equal(
                anchor_idxs, tf.cast(y_true[i][j][5], tf.int32))

            if tf.reduce_any(anchor_eq):
                box = y_true[i][j][0:4]
                box_xy = (y_true[i][j][0:2] + y_true[i][j][2:4]) / 2

                anchor_idx = tf.cast(tf.where(anchor_eq), tf.int32)
                grid_xy = tf.cast(box_xy // (1/grid_size), tf.int32)

                # grid[y][x][anchor] = (tx, ty, bw, bh, obj, class)
                indexes = indexes.write(
                    idx, [i, grid_xy[1], grid_xy[0], anchor_idx[0][0]])
                updates = updates.write(
                    idx, [box[0], box[1], box[2], box[3], 1, y_true[i][j][4]])
                idx += 1

    # tf.print(indexes.stack())
    # tf.print(updates.stack())

    return tf.tensor_scatter_nd_update(
        y_true_out, indexes.stack(), updates.stack())

# %%
def transform_targets(y_train, anchors, anchor_masks, size):
    y_outs = []
    grid_size = size // 32

    # calculate anchor index for true boxes
    anchors = tf.cast(anchors, tf.float32)
    anchor_area = anchors[..., 0] * anchors[..., 1]
    box_wh = y_train[..., 2:4] - y_train[..., 0:2]
    box_wh = tf.tile(tf.expand_dims(box_wh, -2),
                     (1, 1, tf.shape(anchors)[0], 1))
    box_area = box_wh[..., 0] * box_wh[..., 1]
    intersection = tf.minimum(box_wh[..., 0], anchors[..., 0]) * \
        tf.minimum(box_wh[..., 1], anchors[..., 1])
    iou = intersection / (box_area + anchor_area - intersection)
    anchor_idx = tf.cast(tf.argmax(iou, axis=-1), tf.float32)
    anchor_idx = tf.expand_dims(anchor_idx, axis=-1)

    y_train = tf.concat([y_train, anchor_idx], axis=-1)

    for anchor_idxs in anchor_masks:
        y_outs.append(transform_targets_for_output(
            y_train, grid_size, anchor_idxs))
        grid_size *= 2

    return tuple(y_outs)

# %%
def transform_images(x_train, size):
    x_train = tf.image.resize(x_train, (size, size))
    x_train = x_train / 255
    return x_train

# %%
IMAGE_FEATURE_MAP = {
    # 'image/width': tf.io.FixedLenFeature([], tf.int64),
    # 'image/height': tf.io.FixedLenFeature([], tf.int64),
    # 'image/filename': tf.io.FixedLenFeature([], tf.string),
    # 'image/source_id': tf.io.FixedLenFeature([], tf.string),
    # 'image/key/sha256': tf.io.FixedLenFeature([], tf.string),
    'image/encoded': tf.io.FixedLenFeature([], tf.string),
    # 'image/format': tf.io.FixedLenFeature([], tf.string),
    'image/object/bbox/xmin': tf.io.VarLenFeature(tf.float32),
    'image/object/bbox/ymin': tf.io.VarLenFeature(tf.float32),
    'image/object/bbox/xmax': tf.io.VarLenFeature(tf.float32),
    'image/object/bbox/ymax': tf.io.VarLenFeature(tf.float32),
    'image/object/class/text': tf.io.VarLenFeature(tf.string),
    # 'image/object/class/label': tf.io.VarLenFeature(tf.int64),
    # 'image/object/difficult': tf.io.VarLenFeature(tf.int64),
    # 'image/object/truncated': tf.io.VarLenFeature(tf.int64),
    # 'image/object/view': tf.io.VarLenFeature(tf.string),
}

# %%
def parse_tfrecord(tfrecord, class_table, size):
    x = tf.io.parse_single_example(tfrecord, IMAGE_FEATURE_MAP)
    x_train = tf.image.decode_jpeg(x['image/encoded'], channels=3)
    x_train = tf.image.resize(x_train, (size, size))

    class_text = tf.sparse.to_dense(
        x['image/object/class/text'], default_value='')
    labels = tf.cast(class_table.lookup(class_text), tf.float32)
    y_train = tf.stack([tf.sparse.to_dense(x['image/object/bbox/xmin']),
                        tf.sparse.to_dense(x['image/object/bbox/ymin']),
                        tf.sparse.to_dense(x['image/object/bbox/xmax']),
                        tf.sparse.to_dense(x['image/object/bbox/ymax']),
                        labels], axis=1)

    paddings = [[0, FLAGS.yolo_max_boxes - tf.shape(y_train)[0]], [0, 0]]
    y_train = tf.pad(y_train, paddings)

    return x_train, y_train

# %%
def load_tfrecord_dataset(file_pattern, class_file, size=416):
    LINE_NUMBER = -1  # TODO: use tf.lookup.TextFileIndex.LINE_NUMBER
    class_table = tf.lookup.StaticHashTable(tf.lookup.TextFileInitializer(
        class_file, tf.string, 0, tf.int64, LINE_NUMBER, delimiter="\n"), -1)

    files = tf.data.Dataset.list_files(file_pattern)
    dataset = files.flat_map(tf.data.TFRecordDataset)
    return dataset.map(lambda x: parse_tfrecord(x, class_table, size))

# %%
flags.DEFINE_string('class', 'ball', 'the class')
flags.DEFINE_integer('size', 416, 'resize images to')
flags.DEFINE_string(
    'dataset', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export/0.tfrecord', 'path to dataset')

# %%
dataset = load_tfrecord_dataset("C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export/0.tfrecord","ball", 416)
# dataset = dataset.shuffle(512)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-27-8f4e5d605b5f> in <module>
# ----> 1 dataset = load_tfrecord_dataset("C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export/0.tfrecord","ball", 416)
#       2 # dataset = dataset.shuffle(512)
#
# <ipython-input-21-038f31927094> in load_tfrecord_dataset(file_pattern, class_file, size)
#       2     LINE_NUMBER = -1  # TODO: use tf.lookup.TextFileIndex.LINE_NUMBER
#       3     class_table = tf.lookup.StaticHashTable(tf.lookup.TextFileInitializer(
# ----> 4         class_file, tf.string, 0, tf.int64, LINE_NUMBER, delimiter="\n"), -1)
#       5
#       6     files = tf.data.Dataset.list_files(file_pattern)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow_core\python\ops\lookup_ops.py in __init__(self, initializer, default_value, name)
#     288     self._name = name or "hash_table"
#     289     self._table_name = None
# --> 290     super(StaticHashTable, self).__init__(default_value, initializer)
#     291     self._value_shape = self._default_value.get_shape()
#     292
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow_core\python\ops\lookup_ops.py in __init__(self, default_value, initializer)
#     177         self._init_op = self._initialize()
#     178     else:
# --> 179       self._init_op = self._initialize()
#     180
#     181   def _initialize(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow_core\python\ops\lookup_ops.py in _initialize(self)
#     180
#     181   def _initialize(self):
# --> 182     return self._initializer.initialize(self)
#     183
#     184   @property
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow_core\python\ops\lookup_ops.py in initialize(self, table)
#     651       init_op = gen_lookup_ops.initialize_table_from_text_file_v2(
#     652           table.resource_handle, filename, self._key_index, self._value_index,
# --> 653           -1 if self._vocab_size is None else self._vocab_size, self._delimiter)
#     654     ops.add_to_collection(ops.GraphKeys.TABLE_INITIALIZERS, init_op)
#     655     # If the filename tensor is anything other than a string constant (e.g.,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow_core\python\ops\gen_lookup_ops.py in initialize_table_from_text_file_v2(table_handle, filename, key_index, value_index, vocab_size, delimiter, name)
#     356       else:
#     357         message = e.message
# --> 358       _six.raise_from(_core._status_to_exception(e.code, message), None)
#     359   # Add nodes to the TensorFlow graph.
#     360   key_index = _execute.make_int(key_index, "key_index")
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\six.py in raise_from(value, from_value)
#
# NotFoundError: NewRandomAccessFile failed to Create/Open: ball : The system cannot find the file specified.
# ; No such file or directory [Op:InitializeTableFromTextFileV2]
