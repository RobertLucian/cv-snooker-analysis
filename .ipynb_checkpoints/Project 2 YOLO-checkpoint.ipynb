# %%
from PIL import Image
from os import path, makedirs
import os
import re
import pandas as pd
import sys
import argparse
import glob
import tensorflow as tf
import numpy as np
import IPython.display as display

# %%
#must be executed at the beginning of the program
tf.enable_eager_execution()

# %%
base_folder='C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export'
tfr_records = glob.glob(os.path.join(base_folder, "*.tfrecord")) 
tfr_records.sort(key = len) 
print(tfr_records)
# Out:
# ['C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\0.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\1.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\2.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\3.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\4.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\5.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\10.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\11.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRecords-export\\12.tfrecord', 'C:/Users/u721848/Documents/CV/cv-snooker-analysis/labeler 1/Snooker-2-TFRec
# ...

# %%
filenames = [tfr_records]
raw_dataset = tf.data.TFRecordDataset(filenames)
raw_dataset
# Out:
# <TFRecordDatasetV1 shapes: (), types: tf.string>

# %%
for raw_record in raw_dataset.take(2):
    print(repr(raw_record))
# Out:
# <tf.Tensor: id=20, shape=(), dtype=string, numpy=b'\n\x87\xd9\x0c\n\xc9\xd2\x0c\n\rimage/encoded\x12\xb6\xd2\x0c\n\xb2\xd2\x0c\n\xae\xd2\x0c\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x02\x01\x01\x01\x01\x01\x02\x01\x01\x01\x02\x02\x02\x02\x02\x04\x03\x02\x02\x02\x02\x05\x04\x04\x03\x04\x06\x05\x06\x06\x06\x05\x06\x06\x06\x07\t\x08\x06\x07\t\x07\x06\x06\x08\x0b\x08\t\n\n\n\n\n\x06\x08\x0b\x0c\x0b\n\x0c\t\n\n\n\xff\xdb\x00C\x01\x02\x02\x02\x02\x02\x02\x05\x03\x03\x05\n\x07\x06\x07\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xff\xc0\x00\x11\x08\x02\xd0\x05\x00\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd
# ...

# %%
raw_example = next(iter(raw_dataset))
parsed = tf.train.Example.FromString(raw_example.numpy())

parsed.features.feature['image/text']
